# %% [markdown]
# #### Chain Of Thoughts With RAG
# What is Chain-of-Thought (CoT) in RAG?
#
# CoT reasoning breaks down a complex question into intermediate steps, and allows retrieval + reflection at each step before answering.
#
# User Query
#    ↓
# - Step 1: Decompose question → sub-steps (Reason)
# - Step 2: Retrieve docs per step (Act)
# - Step 3: Combine context (Observe)
# - Step 4: Final answer generation (Reflect)

# %%
import os
from typing import List
from pydantic import BaseModel
from langchain_classic.schema import Document
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import TextLoader
from langchain_classic.vectorstores import FAISS
from langchain_classic.text_splitter import RecursiveCharacterTextSplitter
from langgraph.graph import StateGraph, END

# %%
# -------------------------------
# 1. Prepare Vectorstore
# -------------------------------
docs = TextLoader("research_notes.txt",encoding="utf-8").load()
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents(docs)
embedding = HuggingFaceEmbeddings()
vectorstore = FAISS.from_documents(chunks, embedding)
retriever = vectorstore.as_retriever()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 1950.73it/s]

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
llm=init_chat_model("openai/gpt-oss-120b",model_provider="groq")

# %%
# -------------------------------
# 2. LangGraph State Definition
# -------------------------------
class RAGCoTState(BaseModel):
    question: str
    sub_steps: List[str] = []
    retrieved_docs: List[Document] = []
    answer: str = ""

# %%
# -------------------------------
# 3. Nodes
# -------------------------------

# a. Plan sub-questions
def plan_steps(state:RAGCoTState)->RAGCoTState:
    prompt=f"Break the question into 2-3 reasoning steps: \n\n {state.question}"
    result=llm.invoke(prompt).content
    subqs=[line.strip("- ") for line in result.split("\n") if line.strip()]

    return state.model_copy(update={"sub_steps":subqs})

# %%
# b. Retrieve for each step
def retrieve_per_step(state:RAGCoTState)-> RAGCoTState:
    all_docs=[]
    for sub in state.sub_steps:
        docs = retriever.invoke(sub)
        all_docs.extend(docs)
    return state.model_copy(update={"retrieved_docs": all_docs})

# %%
# c. Generate Final Answer
def generate_answer(state: RAGCoTState) -> RAGCoTState:
    
    context = "\n\n".join([doc.page_content for doc in state.retrieved_docs])
    prompt = f"""
You are answering a complex question using reasoning and retrieved documents.

Question: {state.question}

Relevant Information:
{context}

Now synthesize a well-reasoned final answer.
"""
    result = llm.invoke(prompt).content.strip()
    return state.model_copy(update={"answer": result})

# %%
# -------------------------------
# 4. LangGraph Graph
# -------------------------------
builder = StateGraph(RAGCoTState)
builder.add_node("planner", plan_steps)
builder.add_node("retriever", retrieve_per_step)
builder.add_node("responder", generate_answer)

builder.set_entry_point("planner")
builder.add_edge("planner", "retriever")
builder.add_edge("retriever", "responder")
builder.add_edge("responder", END)

graph = builder.compile()
graph

# %%
# -------------------------------
# 5. Run CoT RAG Agent
# -------------------------------
if __name__ == "__main__":
    query = "what are the additional eperiments in Transformer eveluation?"
    state = RAGCoTState(question=query)
    final = graph.invoke(state)

    print("\n🪜 Reasoning Steps:", final["sub_steps"])
    print("\n✅ Final Answer:\n", final["answer"])
# Out:
# 🪜 Reasoning Steps: ['**Step\u202f1 – Identify the baseline evaluation suite**', 'Start by listing the core tasks and metrics that are typically used to assess a Transformer model (e.g., language modeling perplexity, translation BLEU scores, GLUE/SuperGLUE benchmark results, image‑captioning CIDEr, etc.). Knowing the standard set makes it easier to spot what counts as “additional” beyond the baseline.', '**Step\u202f2 – Gather the supplementary experiments reported in the paper (or study)**', 'Look for experiments that go beyond the primary benchmarks, such as:', '**Ablation studies** (removing or modifying components like positional encodings, multi‑head attention, feed‑forward size).', '**Scaling analyses** (varying model depth/width, dataset size, or compute budget).', '**Robustness & generalisation checks** (adversarial attacks, domain shift, noisy inputs, out‑of‑distribution tests).', '**Efficiency measurements** (inference latency, memory footprint, FLOPs, energy consumption).', '**Transfer & fine‑tuning experiments** (performance on downstream tasks after pre‑training on a different corpus).', '**Interpretability probes** (attention pattern visualisation, probing for linguistic structure).', 'Collect the details (what was changed, how it was measured, and the observed effect).', '**Step\u202f3 – Synthesize the findings**', 'Summarise the purpose and outcome of each additional experiment: what aspect of the Transformer’s behavior it illuminates, how it supports (or challenges) the main results, and any practical implications (e.g., which component is most critical, how performance scales, trade‑offs between accuracy and efficiency). This final synthesis ties the extra experiments back to the overall evaluation narrative.']
#
# ✅ Final Answer:
#  **Answer – “Additional Experiments” that were run in the **Transformer Evaluation** (July 2024)**
#
# The evaluation log lists a set of experiments that were *added* on top of the baseline model tests (LLaMA‑2, EfficientFormer, Longformer, Reformer, TinyBERT, etc.).  They fall into three broad categories: **speed / efficiency**, **prompting & reasoning**, and **system‑level / safety**.  Below is a concise, ordered summary of every experiment that was labelled “Additional Experiments” in the document, together with the key purpose and any reported outcome.
#
# | # | Experiment | What was done | Main finding / metric |
# |---|------------|---------------|-----------------------|
# | 1 | **FlashAttention 2** | Integrated the FlashAttention‑2 kernel into LLaMA‑2 (and implicitly into any other dense‑attention model). | Cut *context‑window* latency by **≈ 50 %** (e.g., from ~300 ms → ~150 ms on an A100). |
# | 2 | **Chain‑of‑Thought (CoT) prompting** | Switched from “direct answer” prompts to a multi‑step reasoning style (CoT) and also tried a *reflective* variant (self‑check after the first answer). | CoT ↑ accuracy on logical reasoning tasks by **~8 %**; reflective prompting adds another **~3 %** gain. |
# | 3 | **Tool‑augmented prompting** | Built a LangGraph‑driven agent that can call external tools (Wikipedia lookup, SQL query) during generation. | Demonstrated dynamic retrieval‑agent reasoning (e.g., “Give me customer insights from SQL, verify with wiki”). No single numeric score was reported, but qualitative notes say the pipeline *outperformed static RAG* in correctness. |
# | 4 | **Human‑evaluation protocol** | Ran a double‑blind rating by internal annotators on **fluency, helpfulness, correctness**; complemented it with a synthetic evaluator (GPT‑4). | Provides a reliable benchmark for future model‑vs‑human win‑rate (baseline LLaMA‑2: 75 % win‑rate). |
# | 5 | **Retrieval experiments (Hybrid dense + sparse)** | Compared two retrieval stacks: <br>• **Weaviate** (vector + GraphQL filtering) <br>• **FAISS + BM25** reranking | FAISS is **more efficient** (lower latency, smaller index) but yields a **slightly lower recall** than Weaviate. Weaviate’s GraphQL filter proved useful for domain‑specific constraints. |
# | 6 | **LoRA (Low‑Rank Adaptation) tuning** | Fine‑tuned models with LoRA adapters (rank = 8, dropout = 0.05) via the PEFT library. | Cuts GPU memory consumption by **≈ 60 %** while preserving task performance (e.g., LLaMA‑2 win‑rate unchanged). |
# | 7 | **Safety & Red‑team testing** | Added three safety layers: <br>• **Detoxify** toxicity detector <br>• Zero‑shot out‑of‑scope classifier <br>• Manual red‑team adversarial prompts | No quantitative numbers are given, but the pipeline flagged a set of previously unseen toxic or off‑topic outputs, confirming the filters work as intended. |
# | 8 | **Reflective prompting (sub‑category of CoT)** | After an initial answer, the model is asked to “double‑check” its reasoning before final output. | Improves accuracy **+3 %** on the same logic benchmark used for CoT. |
# | 9 | **Prompt‑format experiments** (mentioned under LLaMA‑2) | Tested three prompt syntaxes: **Alpaca**, **ChatML**, and a custom **XML‑based memory‑tag** format. | No explicit scores, but the XML‑based tags were noted to help the model retain long‑term context in RAG scenarios. |
#
# ### How the experiments fit together
#
# | Category | Experiments | Goal |
# |----------|-------------|------|
# | **Performance / Efficiency** | FlashAttention 2, LoRA tuning | Reduce latency & memory while keeping accuracy. |
# | **Reasoning & Prompt Engineering** | Chain‑of‑Thought, Reflective prompting, Prompt‑format tests, Tool‑augmented prompting | Boost logical correctness and make the model capable of external tool use. |
# | **Retrieval & RAG** | Hybrid dense + sparse retrieval (FAISS vs Weaviate) | Find the best trade‑off between speed, recall, and filtering capability. |
# | **Evaluation & Safety** | Human‑evaluation protocol, GPT‑4 synthetic evaluator, Detoxify + out‑of‑scope filter + red‑team | Provide reliable quality metrics and guard against harmful outputs. |
#
# ### TL;DR
#
# The **additional experiments** in the Transformer evaluation are:
#
# 1. **FlashAttention 2** – halves context latency.
# 2. **Chain‑of‑Thought & Reflective prompting** – 8 % + 3 % accuracy gains on logic tasks.
# 3. **Tool‑augmented prompting** (LangGraph + Wikipedia + SQL).
# 4. **Human evaluation protocol** (fluency, helpfulness, correctness) plus GPT‑4 synthetic judge.
# 5. **Hybrid retrieval** (Weaviate vs FAISS + BM25).
# 6. **LoRA tuning** (rank 8, dropout 0.05) – 60 % GPU memory reduction.
# 7. **Safety stack** (Detoxify, out‑of‑scope classifier, red‑team testing).
# 8. **Prompt‑format experiments** (Alpaca, ChatML, XML‑memory tags).
#
# These experiments collectively explore speed improvements, better reasoning, richer tool use, more robust evaluation, efficient retrieval, lightweight fine‑tuning, and safety—providing a comprehensive extension to the core transformer benchmarks.
